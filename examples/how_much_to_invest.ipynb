# %%
import numpy as np
import pandas as pd
from finance_calculators.calc_contributions import total_contribution, reformat, MaxContribution

# %%
# Yearly income estimates using hourly rates and 52 pay periods.
# part-time, full-time, 4 hours overtime and 8 hours overtime
hours_per_week = np.array([15, 20, 30, 40, 50, 60])
hourly_rate = 75
weeks_in_a_year= 52
brute_income_yr= hours_per_week.reshape(-1,1) * hourly_rate * weeks_in_a_year
brute_income_yr
# Out:
# array([[ 58500],
#        [ 78000],
#        [117000],
#        [156000],
#        [195000],
#        [234000]])

# %%
brute_income_yr = np.array([50,75,100,150,200,250,500]).reshape(-1,1) * 1000

# %%
year = 2026
max_contritions_dict = MaxContribution(year)
max_employee_contribution = max_contritions_dict.get("401k employee", year)

#This is an estimate. The max is 70000 - employee contribution for 2025
max_employer_contribution = max_contritions_dict.get("401k max", year) - max_employee_contribution

# Multiple investment percentages
percentage   = np.array([ .10, .12, .13, .14, .15, .16, .17, .18]).reshape(1,-1)
match_percentage  = np.array([.01, .02, .03, .05,.07, .10,.20, .25]).reshape(1,-1)

# Employee contribution per month
amounts_df = total_contribution(brute_income_yr,percentage,periods=12,max_contribution=max_employee_contribution)
amounts = reformat(amounts_df.copy(),periods=12,contribution_type= "employee")
display(amounts)

# Employer contribution per month
amounts_df_matching = total_contribution(brute_income_yr,match_percentage,periods=12,max_contribution=max_employer_contribution)
amounts = reformat(amounts_df_matching.copy(),periods=12,contribution_type= "employer")
display(amounts)
# Out:
# <style type="text/css">
# #T_8853f caption {
#   font-size: 32px;
# }
# #T_8853f_row0_col0, #T_8853f_row0_col1, #T_8853f_row0_col2, #T_8853f_row0_col3, #T_8853f_row0_col4, #T_8853f_row0_col5, #T_8853f_row0_col6, #T_8853f_row0_col7, #T_8853f_row1_col0, #T_8853f_row1_col1, #T_8853f_row1_col2, #T_8853f_row1_col3, #T_8853f_row1_col4, #T_8853f_row1_col5, #T_8853f_row1_col6, #T_8853f_row1_col7, #T_8853f_row2_col0, #T_8853f_row2_col1, #T_8853f_row2_col2, #T_8853f_row2_col3, #T_8853f_row2_col4, #T_8853f_row2_col5, #T_8853f_row2_col6, #T_8853f_row2_col7, #T_8853f_row3_col0, #T_8853f_row3_col1, #T_8853f_row3_col2, #T_8853f_row3_col3, #T_8853f_row3_col4, #T_8853f_row3_col5, #T_8853f_row4_col0, #T_8853f_row4_col1 {
#   color: white;
# }
# ...

# %%
# Employee contribution per year
amounts_df_yr = total_contribution(brute_income_yr,percentage,periods=1,max_contribution=max_employee_contribution)
amounts = reformat(amounts_df_yr.copy(),periods=1, contribution_type= "employee")
display(amounts)

# Employer contribution per year
amounts_df_yr_matching = total_contribution(brute_income_yr,match_percentage,periods=1,max_contribution=max_employer_contribution)
amounts = reformat(amounts_df_yr_matching.copy(),periods=1,contribution_type= "employer")
display(amounts)
# Out:
# <style type="text/css">
# #T_479e7 caption {
#   font-size: 32px;
# }
# #T_479e7_row0_col0, #T_479e7_row0_col1, #T_479e7_row0_col2, #T_479e7_row0_col3, #T_479e7_row0_col4, #T_479e7_row0_col5, #T_479e7_row0_col6, #T_479e7_row0_col7, #T_479e7_row1_col0, #T_479e7_row1_col1, #T_479e7_row1_col2, #T_479e7_row1_col3, #T_479e7_row1_col4, #T_479e7_row1_col5, #T_479e7_row1_col6, #T_479e7_row1_col7, #T_479e7_row2_col0, #T_479e7_row2_col1, #T_479e7_row2_col2, #T_479e7_row2_col3, #T_479e7_row2_col4, #T_479e7_row2_col5, #T_479e7_row2_col6, #T_479e7_row2_col7, #T_479e7_row3_col0, #T_479e7_row3_col1, #T_479e7_row3_col2, #T_479e7_row3_col3, #T_479e7_row3_col4, #T_479e7_row3_col5, #T_479e7_row4_col0, #T_479e7_row4_col1 {
#   color: white;
# }
# ...

# %%
# TODO Create a dataframe that adds the two contributions using one employer matching percentage
total_df = pd.DataFrame(amounts_df_yr.values + amounts_df_yr_matching.values,columns=amounts_df_yr.columns)
total_df.Income = amounts_df_yr.Income
columns = [f"{int(c)}+{int(b)}%" for b,c in zip(amounts_df_yr.columns.values[1:], amounts_df_yr_matching.columns.values[1:])]
total_df.columns = [amounts_df_yr.columns.values[0]] + columns
amounts = reformat(total_df.copy(),periods=1,contribution_type= "total")
display(amounts)
# Out:
# <style type="text/css">
# #T_8218d caption {
#   font-size: 32px;
# }
# ...

# %%
#https://www.calculator.net/401k-calculator.html
#https://www.calculatorsoup.com/calculators/financial/future-value-annuity-calculator.php
i = 10/100 #APY
G = .01 # Annual income increase
N = 65 - 38 # Assuming retiring at 65yrs old
T = 1 #ordinary annuity. Beginning of the period
T = 0 #annuity due. End of the period

amount_df = total_df.copy()

if G<=0.0:
  amount_df.iloc[:,1:] *= (np.power(1+i,N)-1)*(1+i*T)/i #Not assuming annual growth
  print("Assumming no annual growth")
else:
  # https://www.calculatorsoup.com/calculators/financial/future-value-calculator.php#formulas
  # https://www.calculator.net/investment-calculator.html?ctype=endamount&ctargetamountv=1%2C000%2C000&cstartingprinciplev=0&cyearsv=10&cinterestratev=6&ccompound=monthly&ccontributeamountv=7%2C000&cadditionat1=end&ciadditionat1=annually&printit=0&x=Calculate#calresult
  # TODO update this to be compounded monthly, yearly, daily, etc...
  # This is off by a some amount when compared to the calculatorsoup result
  amount_df.iloc[:,1:] *= (np.power(1+i,N)-np.power(1+G,N))*(1+i*T)/(i-G) #Assuming annual growth
  print("Assumming annual growth")

title = f"Total Retirement Estimate after {N}yrs"

formated_future_value = reformat(amount_df.copy(),periods=1,contribution_type= False, flag_max=False,title=title)
display(formated_future_value)
# Out:
# Assumming annual growth
# <style type="text/css">
# #T_f4e84 caption {
#   font-size: 32px;
# }
# </style>
# <table id="T_f4e84">
#   <caption>Total Retirement Estimate after 27yrs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4e84_level0_col0" class="col_heading level0 col0" >1+10%</th>
#       <th id="T_f4e84_level0_col1" class="col_heading level0 col1" >2+12%</th>
#       <th id="T_f4e84_level0_col2" class="col_heading level0 col2" >3+13%</th>
#       <th id="T_f4e84_level0_col3" class="col_heading level0 col3" >5+14%</th>
#       <th id="T_f4e84_level0_col4" class="col_heading level0 col4" >7+15%</th>
#       <th id="T_f4e84_level0_col5" class="col_heading level0 col5" >10+16%</th>
#       <th id="T_f4e84_level0_col6" class="col_heading level0 col6" >20+17%</th>
#       <th id="T_f4e84_level0_col7" class="col_heading level0 col7" >25+18%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Income</th>
# ...
